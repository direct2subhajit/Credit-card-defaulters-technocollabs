# %% [markdown]
# **Run the two cells below before you begin. These will set the notebook to autosave every 10 seconds, import the necessary libraries for this challenge, and set figure appearance.**

# %%
# %autosave 10
# Out:
# Autosaving every 10 seconds

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 400
mpl.rcParams['font.size'] = 4

# %% [markdown]
# **To begin, import data set `cleaned_data.csv` and create lists of feature names for the remaining financial features: `'BILL_AMT1'`, `'BILL_AMT2'`, `'BILL_AMT3'`, `'BILL_AMT4'`, `'BILL_AMT5'`, `'BILL_AMT6'`,  `'PAY_AMT1'`, `'PAY_AMT2'`, `'PAY_AMT3'`, `'PAY_AMT4'`, `'PAY_AMT5'`, and `'PAY_AMT6'`.**
#
# **Name the features `bill_feats` and `pay_amt_feats`, respectively.**

# %%
# Import the dataset
df = pd.read_csv('cleaned_data.csv')
df.head()
# Out:
#               ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  \
# 0  798fc410-45c1      20000    2          2         1   24      2      2
# 1  8a8c8f3b-8eb4     120000    2          2         2   26     -1      2
# 2  85698822-43f5      90000    2          2         2   34      0      0
# 3  0737c11b-be42      50000    2          2         1   37      0      0
# 4  3b7f77cc-dbc0      50000    1          2         1   57     -1      0
#
#    PAY_3  PAY_4  ...  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0     -1     -1  ...         0         0         0         0
# 1      0      0  ...      1000      1000         0      2000
# 2      0      0  ...      1000      1000      1000      5000
# 3      0      0  ...      1200      1100      1069      1000
# 4     -1      0  ...     10000      9000       689       679
#
#    default payment next month  EDUCATION_CAT  graduate school  high school  \
# 0                           1     university                0            0
# 1                           1     university                0            0
# 2                           0     university                0            0
# 3                           0     university                0            0
# 4                           0     university                0            0
#
#    others  university
# 0       0           1
# 1       0           1
# 2       0           1
# 3       0           1
# 4       0           1
#
# [5 rows x 30 columns]

# %%
# Create lists `bill_feats` and `pay_amt_feats`
bill_feats=['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6']

pay_amt_feats=['PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5','PAY_AMT6']

# %% [markdown]
# ____________________________________________________________________________________
# **Next, use `.describe()` to examine statistical summaries of the bill amount features**

# %%
df[bill_feats].describe().T
# Out:
#              count          mean           std       min      25%      50%  \
# BILL_AMT1  26664.0  51405.730723  73633.687106 -165580.0  3580.00  22361.0
# BILL_AMT2  26664.0  49300.001500  70934.549534  -69777.0  2999.75  21150.0
# BILL_AMT3  26664.0  47026.340047  68705.359524 -157264.0  2627.25  20079.5
# BILL_AMT4  26664.0  43338.894539  64275.250740 -170000.0  2341.75  19037.0
# BILL_AMT5  26664.0  40338.136701  60705.944083  -81334.0  1745.00  18066.0
# BILL_AMT6  26664.0  38889.872337  59432.541657 -339603.0  1256.00  17005.0
#
#                 75%       max
# BILL_AMT1  67649.75  746814.0
# BILL_AMT2  64395.50  671563.0
# BILL_AMT3  60360.00  855086.0
# BILL_AMT4  54727.50  706864.0
# BILL_AMT5  50290.50  823540.0
# BILL_AMT6  49253.75  699944.0

# %% [markdown]
# Reflect on what you see. Does it make sense?

# %% [markdown]
# ___________________________________________________________________________________
# **Then you should visualize the bill amount features using a 2 by 3 grid of histogram plots.**
# > Hint: You can use 20 bins for this visualization.

# %%
mpl.rcParams['font.size'] = 4
df[bill_feats].hist(bins=20, layout=(2,3))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022A284260A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022A28197EE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022A297BF370>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022A297ED7C0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022A29817C10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022A29843100>]],
#       dtype=object)

# %% [markdown]
# ________________________________________________________________________
# **Next, obtain the `.describe()` summary of the payment amount features.**

# %%
df[pay_amt_feats].describe().T
# Out:
#             count         mean           std  min      25%     50%      75%  \
# PAY_AMT1  26664.0  5704.085771  16699.398632  0.0  1000.00  2114.5  5027.00
# PAY_AMT2  26664.0  5881.109848  21214.309852  0.0   802.00  2007.0  5000.00
# PAY_AMT3  26664.0  5259.514964  17265.439561  0.0   390.00  1822.0  4556.25
# PAY_AMT4  26664.0  4887.048717  15956.349371  0.0   294.75  1500.0  4050.50
# PAY_AMT5  26664.0  4843.729973  15311.721795  0.0   242.75  1500.0  4082.75
# PAY_AMT6  26664.0  5257.843047  17635.468185  0.0   111.00  1500.0  4015.00
#
#                 max
# PAY_AMT1   873552.0
# PAY_AMT2  1227082.0
# PAY_AMT3   889043.0
# PAY_AMT4   621000.0
# PAY_AMT5   426529.0
# PAY_AMT6   528666.0

# %% [markdown]
#     Does this make sense?

# %% [markdown]
# _______________________________________________________________________________________
# **Next, plot a histogram of the bill payment features similar to the bill amount features,
# but also apply some rotation to the x-axis labels with the `xrot` keyword argument
# so that they don't overlap. In any plotting function, you can include the `xrot=<angle>`
# keyword argument to rotate x-axis labels by a given angle in degrees.**

# %%
mpl.rcParams['font.size'] = 4
df[pay_amt_feats].hist(bins=20, layout=(2,3),xrot= 30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022A2AC41FA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022A2E88B610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022A2E8D2AC0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022A2E90A280>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022A2E930A00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022A32266100>]],
#       dtype=object)

# %% [markdown]
#     Consider these results.

# %% [markdown]
# ______________________________________________________________________________________________
# **Then, use a Boolean mask to see how many of the payment amount data are exactly equal to 0. Review the results of the generated mask using `.head()` and `.sum()`.**

# %%
# Create Boolean mask
payment_amt_mask = df[pay_amt_feats] == 0

# %%
# Use `.head()`
payment_amt_mask.head()
# Out:
#    PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 0      True     False      True      True      True      True
# 1      True     False     False     False      True     False
# 2     False     False     False     False     False     False
# 3     False     False     False     False     False     False
# 4     False     False     False     False     False     False

# %%
# Use `.sum()`
payment_amt_mask.sum()
# Out:
# PAY_AMT1    4656
# PAY_AMT2    4833
# PAY_AMT3    5293
# PAY_AMT4    5697
# PAY_AMT5    5981
# PAY_AMT6    6373
# dtype: int64

# %% [markdown]
#      Does this make sense given the histogram in the previous step?

# %% [markdown]
# _______________________________________________________________________________________________________________________________
# **Finally, ignoring the payments of 0 using the mask you created in the previous step, use pandas `.apply()` and NumPy's `np.log10()` to plot histograms of logarithmic transformations of the non-zero payments.**
# > Hint: You can use `.apply()` to apply any function, including `log10`, to all the elements of a DataFrame or a column using the following syntax: `.apply(<function_name>)`.

# %%
df[pay_amt_feats][~payment_amt_mask].apply(lambda x: np.log10(x)).hist()
plt.show()
